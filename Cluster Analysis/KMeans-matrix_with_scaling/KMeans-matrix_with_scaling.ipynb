# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans
from sklearn import preprocessing
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Clustering (scaled data)

# %%
plot_layout = pd.DataFrame(columns=['x','y'])
for l in range (0,3):
    for m in range (0,3):
        plot_layout = pd.concat([plot_layout, pd.DataFrame([{'x':l, 'y':m}])], axis=0, ignore_index=True)

wcss = []        

data = pd.read_csv('iris_dataset.csv')
x_scaled = preprocessing.scale(x)
fig, axs = plt.subplots(3, 3, figsize=(14, 14))
for i in range (2,11):
    kmeans = KMeans(i)
    kmeans.fit(x_scaled)
    wcss.append(kmeans.inertia_)
    identified_clusters = kmeans.fit_predict(x_scaled)
    data_with_cluster = data.copy()
    data_with_cluster['CLuster'] = identified_clusters
    axs[plot_layout.iloc[i-2,0],plot_layout.iloc[i-2,1]].scatter(data_with_cluster['sepal_length'],data_with_cluster['sepal_width'],c=data_with_cluster['CLuster'], cmap='rainbow')
    plt.xlabel("sepal_length")
    plt.ylabel("sepal_width")
plt.show()

plt.plot(range(2,11),wcss)
plt.xlabel('Number of CLusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')
